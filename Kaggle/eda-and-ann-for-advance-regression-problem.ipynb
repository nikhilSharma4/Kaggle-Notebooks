# %% [markdown]
# Piyush Singla Kaggle link -> https://www.kaggle.com/mpiyu20/account
# Nikhil Singla Kaggle link -> https://www.kaggle.com/nikhilsharma4

# %% [markdown]
# ## Housing price prediction using ANN

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import pandas as pd
import numpy as np

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the dataset

# %%
df_train = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
df_test = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# Processing missing values

# %%
df_train.isnull().sum().sort_values(ascending =False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %% [markdown]
# Percentage of missing data

# %%
df_train.isnull().sum().sort_values(ascending =False).head(20)/len(df_train)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageCond      0.055479
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtExposure    0.026027
# BsmtFinType2    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# MasVnrType      0.005479
# Electrical      0.000685
# Utilities       0.000000
# dtype: float64

# %% [markdown]
# Removing the parameters with missing data

# %%
df_train.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage'],axis=1,inplace=True)
df_test.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage',],axis=1,inplace=True)

# %% [markdown]
# Treatment of left parameters having missing values

# %%
import random
missing_values = df_train.columns[df_train.isna().any()].to_list()
for each in missing_values:
    if (df_train[each].dtypes =='float64'):
        minimum= int(df_train[each].quantile(0.25))
        maximum= int(df_train[each].quantile(0.75))
        A=df_train[df_train[each].isnull()].index.tolist()
        for i in A:
            df_train.loc[i,each]=random.randint(minimum,maximum)
        df_train[each]=pd.to_numeric(df_train[each])
   

    elif(df_train[each].dtypes == 'object'):
        if ('True' in str(df_train[each].str.contains('No').unique().tolist())):
            df_train[each].fillna('No',inplace=True)
        elif('True' in str(df_train[each].str.contains('None').unique().tolist())):
            df_train[each].fillna('None',inplace=True)
        elif('True' in str(df_train[each].str.contains('Unf').unique().tolist())):
            df_train[each].fillna('Unf',inplace=True)
        else:
            A=df_train[df_train[each].isnull()].index.tolist()
            unique = df_train[each].unique().tolist()
            unique=pd.Series(unique).dropna().tolist()
            for i in A:
                df_train.loc[i,each]=random.choice(unique)


missing_values = df_test.columns[df_test.isna().any()].to_list()
for each in missing_values:
    if (df_test[each].dtypes =='float64'):
        minimum= int(df_test[each].quantile(0.25))
        maximum= int(df_test[each].quantile(0.75))
        A=df_test[df_test[each].isnull()].index.tolist()
        for i in A:
            df_test.loc[i,each]=random.randint(minimum,maximum)
        df_test[each]=pd.to_numeric(df_test[each])
   

    elif(df_test[each].dtypes == 'object'):
        if ('True' in str(df_test[each].str.contains('No').unique().tolist())):
            df_test[each].fillna('No',inplace=True)
        elif('True' in str(df_test[each].str.contains('None').unique().tolist())):
            df_test[each].fillna('None',inplace=True)
        elif('True' in str(df_test[each].str.contains('Unf').unique().tolist())):
            df_test[each].fillna('Unf',inplace=True)
        else:
            A=df_test[df_test[each].isnull()].index.tolist()
            unique = df_test[each].unique().tolist()
            unique=pd.Series(unique).dropna().tolist()
            for i in A:
                df_test.loc[i,each]=random.choice(unique)

# %% [markdown]
# Removing the Id column

# %%
df_train.drop(['Id'],axis=1,inplace=True)
df_test.drop(['Id'],axis=1,inplace=True)

# %% [markdown]
# Now checking the correlation between continuous parameters and plotting the heatmap

# %% [markdown]
# # Exploratory data analysis

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df_train.corr(),annot=True,cmap='coolwarm')

# %%
plt.figure(figsize=(10,5))
df_train.corr()['SalePrice'].sort_values().drop('SalePrice').plot(kind='bar')

# %% [markdown]
# For continous parameters, the most correlated values to Sale Price are given in the above plot

# %% [markdown]
# Now, analysing some most correlated parameters using Seaborn

# %%
fig = plt.figure(figsize=(15,10));   
ax1 = fig.add_subplot(3,4,1);  
ax2 = fig.add_subplot(3,4,2);
ax3 = fig.add_subplot(3,4,3);  
ax4 = fig.add_subplot(3,4,4);
ax5 = fig.add_subplot(3,4,5);  
ax6 = fig.add_subplot(3,4,6);
ax7 = fig.add_subplot(3,4,7);  
ax8 = fig.add_subplot(3,4,8);
ax9 = fig.add_subplot(3,4,9);  
ax10 = fig.add_subplot(3,4,10);
ax11 = fig.add_subplot(3,4,11);  
ax12 = fig.add_subplot(3,4,12);

sns.boxplot("OverallQual", "SalePrice", data=df_train,ax=ax1)
sns.scatterplot("GrLivArea", "SalePrice", data=df_train, ax=ax2)
sns.boxplot("GarageCars", "SalePrice", data=df_train,ax=ax3)
sns.scatterplot("GarageArea", "SalePrice", data=df_train, ax=ax4)
sns.scatterplot("TotalBsmtSF", "SalePrice", data=df_train,ax=ax5)
sns.scatterplot("1stFlrSF", "SalePrice", data=df_train, ax=ax6)
sns.boxplot("FullBath", "SalePrice", data=df_train,ax=ax7)
sns.boxplot("TotRmsAbvGrd", "SalePrice", data=df_train, ax=ax8)
sns.scatterplot("YearBuilt", "SalePrice", data=df_train,ax=ax9)
sns.scatterplot("YearRemodAdd", "SalePrice", data=df_train, ax=ax10)
sns.boxplot("MasVnrType", "SalePrice", data=df_train,ax=ax11)
sns.boxplot("Fireplaces", "SalePrice", data=df_train, ax=ax12)
plt.tight_layout()

# %% [markdown]
# #### Analysis from the above plot
# Overall Quality
# - SalePrice follows a linear relation with Overall quality of the house(as obvious)
# - When OverallQual = 10, the range of SalePrice is between 350,000 to 500,000
#
# Garage Cars
# - Evidenty, if the house has size of garage for accomodating 3 cars, the selling price will be more
# - There are only 5 houses having 4 car space garage, so we can't say much about it, but the prices are lower than 3 car space houses
#
# FullBath, Total Rooms above ground and Fireplaces
# - More number of these parameter in the house, more is the selling price of the house
# - When the parameter starts to increase the variation in SalePrice also increases because it starts depending on other paramters more to make an accurate prediction.
#
# MasVnrType
# - Masonry veneer Stone type has more selling price followed by brick face and common brick
#
# Scatter Plots
# - all the scatterplots including GRLivArea, GarageArea, 1stFlrSF and TotalBsmtSF follows a linear trend with Sale Price

# %%
fig = plt.figure(figsize=(15,10));   
ax1 = fig.add_subplot(2,1,1);  
ax2 = fig.add_subplot(2,1,2);
sns.distplot(df_train['YearBuilt'],bins=50,color='black',ax=ax1)
sns.distplot(df_train['YearRemodAdd'],bins=50,color='black',ax=ax2)

# %% [markdown]
# Most of the houses were build in the 2000's and big chunk in 1950's and 1960's. Most of the houses were remodelled/rebuilt in 1950

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='TotRmsAbvGrd',y='GrLivArea',data=df_train)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='FullBath',y='2ndFlrSF',data=df_train,hue='HalfBath',palette="BuGn_r")

# %% [markdown]
# Number of half baths in a house is independent of full baths. As, mostly in all houses the number of half baths is 1

# %%
plt.figure(figsize=(10,5))
df_train.corr()['OverallQual'].sort_values().drop(['OverallQual','SalePrice']).plot(kind='bar')

# %% [markdown]
# Above plot define the parameters on which the overall quality of the house depends, that are Garage living area, Garage cars, year it was built and No. of full baths

# %% [markdown]
# #### Analysis on catagorical features with dtype object

# %%
catogorical_features_ = np.array([df_train.columns[df_train.dtypes == 'object'].to_list()])
catogorical_features_
# Out:
# array([['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#         'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#         'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#         'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#         'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#         'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#         'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#         'Functional', 'GarageType', 'GarageFinish', 'GarageQual',
#         'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']],
#       dtype='<U13')

# %%
df_train['Utilities'].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
# All the records in utilities are mostly AllPub 
df_train.drop('Utilities',axis=1,inplace=True)
df_test.drop('Utilities',axis=1,inplace=True)

# %%
fig = plt.figure(figsize=(20,15));   
ax1 = fig.add_subplot(4,4,1);  
ax2 = fig.add_subplot(4,4,2);
ax3 = fig.add_subplot(4,4,3);  
ax4 = fig.add_subplot(4,4,4);
ax5 = fig.add_subplot(4,4,5);  
ax6 = fig.add_subplot(4,4,6);
ax7 = fig.add_subplot(4,4,7);  
ax8 = fig.add_subplot(4,4,8);
ax9 = fig.add_subplot(4,4,9);  
ax10 = fig.add_subplot(4,4,10);
ax11 = fig.add_subplot(4,4,11);  
ax12 = fig.add_subplot(4,4,12);
ax13 = fig.add_subplot(4,4,13);  
ax14 = fig.add_subplot(4,4,14);
ax15 = fig.add_subplot(4,4,15);  
ax16 = fig.add_subplot(4,4,16);

sns.boxplot(x="LotShape",y= "SalePrice", data=df_train,ax=ax1)
sns.boxplot("SaleCondition", "SalePrice", data=df_train, ax=ax2)
sns.boxplot("LandSlope", "SalePrice", data=df_train,ax=ax3)
sns.boxplot("Condition1", "SalePrice", data=df_train, ax=ax4)
sns.boxplot("BldgType", "SalePrice", data=df_train,ax=ax5)
sns.boxplot("HouseStyle", "SalePrice", data=df_train, ax=ax6)
sns.boxplot("RoofStyle", "SalePrice", data=df_train,ax=ax7)
sns.boxplot("Exterior1st", "SalePrice", data=df_train, ax=ax8)
sns.boxplot("Exterior2nd", "SalePrice", data=df_train,ax=ax9)
sns.boxplot("ExterQual", "SalePrice", data=df_train, ax=ax10)
sns.boxplot("ExterCond", "SalePrice", data=df_train,ax=ax11)
sns.boxplot("Foundation", "SalePrice", data=df_train, ax=ax12)
sns.boxplot("HeatingQC", "SalePrice", data=df_train,ax=ax13)
sns.boxplot("CentralAir", "SalePrice", data=df_train, ax=ax14)
sns.boxplot("KitchenQual", "SalePrice", data=df_train,ax=ax15)
sns.boxplot("SaleType", "SalePrice", data=df_train, ax=ax16)
plt.tight_layout()

# %% [markdown]
# Lotshape
# - Houses with IR3 type of lots have maximum SalePrice
#
# SaleConditions
# - It is an important attribute as vatiation in SalePrice is more in it with the change in the parameters.
# - Houses with partial salescondition has maximum sales.
#
# LandSlope does not play an integral part in estimation of SalePrice
#
# Condition 1
# - So people prefer to pay more for the lots within the range of 200' to the north-south rail-road.
# - People prefer to pay less for the lots adjacent to arterial street.
#
# HouseStyle
# - 2 story and 1 story housing styles have better sales price than the other ones.
# - The other housing styles follow the constant trends for the sales price.
#
# ExterQual
# - People are willing to pay more for the houses having excellent external quality.
#
# SaleType
# - The salesprice of the houses which are freshly constructed are maximum.

# %%
df_train['Foundation'].value_counts()
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
fig = plt.figure(figsize=(20,10));   
ax1 = fig.add_subplot(1,2,1);  
ax2 = fig.add_subplot(1,2,2);
sns.boxplot("Exterior1st", "SalePrice", data=df_train, ax=ax1)
sns.boxplot("Exterior2nd", "SalePrice", data=df_train,ax=ax2)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(15,10));   
ax1 = fig.add_subplot(2,1,1);  
ax2 = fig.add_subplot(2,1,2);
sns.distplot(df_train['1stFlrSF'],bins=30,color='black',ax=ax1)
sns.distplot(df_train['2ndFlrSF'],bins=10,color='black',ax=ax2)

# %% [markdown]
# - 1st floor sqaure feet has a normal distribution
# - Houses with 2nd floor has around 0 to 250 square feet of area with some houses of range of 500 to 1000 square feet

# %% [markdown]
# #### Converting catagorical features into dummy variable using pandas get dummies method

# %%
catogorical_features_ = np.delete(catogorical_features_,np.where(catogorical_features_=='Utilities'))

# %%
test_match=[]
for i,feature in enumerate(catogorical_features_): 
    test_match.append( (feature,(df_train[feature].nunique()  -  df_test[feature].nunique())))
    if (df_train[feature].nunique()  -  df_test[feature].nunique()) != 0:
        df_train.drop(feature,axis=1,inplace=True)
        df_test.drop(feature,axis=1,inplace=True)

# %%
print(test_match)
# Out:
# [('Street', 0), ('LotShape', 0), ('LandContour', 0), ('LotConfig', 0), ('LandSlope', 0), ('Neighborhood', 0), ('Condition1', 0), ('Condition2', 3), ('BldgType', 0), ('HouseStyle', 1), ('RoofStyle', 0), ('RoofMatl', 4), ('Exterior1st', 2), ('Exterior2nd', 1), ('MasVnrType', 0), ('ExterQual', 0), ('ExterCond', 0), ('Foundation', 0), ('BsmtQual', 0), ('BsmtCond', 0), ('BsmtExposure', 0), ('BsmtFinType1', 0), ('BsmtFinType2', 0), ('Heating', 2), ('HeatingQC', 0), ('CentralAir', 0), ('Electrical', 1), ('KitchenQual', 0), ('Functional', 0), ('GarageType', 0), ('GarageFinish', 0), ('GarageQual', 1), ('GarageCond', 0), ('PavedDrive', 0), ('SaleType', 0), ('SaleCondition', 0)]

# %%
catogorical_features_ = np.array([df_train.columns[df_train.dtypes == 'object'].to_list()])
dummies = []
concat_dummies=[]
for i,feature in enumerate(catogorical_features_[0]):
    dummies.append(pd.get_dummies(df_train[feature],drop_first=True))
    df_train = pd.concat([df_train,dummies[i]],axis=1)

# %%
df_train.drop(['MSZoning', 'Street', 'LotShape', 'LandContour','LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
               'BldgType', 'RoofStyle','MasVnrType', 'ExterQual','Foundation',  'HeatingQC', 'CentralAir',
         'KitchenQual', 'Functional', 'GarageFinish','PavedDrive', 'SaleType', 'SaleCondition','ExterCond',
               'GarageCond',
               'GarageType','GarageYrBlt','BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtCond','BsmtQual'],
              axis=1,inplace=True)

# %%
catogorical_features_ = np.array([df_test.columns[df_test.dtypes == 'object'].to_list()])
dummies = []
concat_dummies=[]
for i,feature in enumerate(catogorical_features_[0]):
    dummies.append(pd.get_dummies(df_test[feature],drop_first=True))
    df_test = pd.concat([df_test,dummies[i]],axis=1)

# %%
df_test.drop(['MSZoning', 'Street', 'LotShape', 'LandContour','LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
               'BldgType', 'RoofStyle','MasVnrType', 'ExterQual','Foundation',  'HeatingQC', 'CentralAir',
         'KitchenQual', 'Functional', 'GarageFinish','PavedDrive', 'SaleType', 'SaleCondition','ExterCond',
             'GarageCond','GarageType','GarageYrBlt','BsmtExposure','BsmtFinType2','BsmtFinType1','BsmtCond','BsmtQual'],axis=1,inplace=True)

# %% [markdown]
# # Artificial Neural Network

# %%
X_train = np.array(df_train.drop('SalePrice',axis=1))
y_train = np.array(df_train['SalePrice'])
X_test = np.array(df_test)

# %%
print('Shape of X_train {} \nShape of y_test {}\nShape of X_test {}'.format(X_train.shape,y_train.shape,X_test.shape))
# Out:
# Shape of X_train (1460, 167)
# Shape of y_test (1460,)
# Shape of X_test (1459, 167)

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %%
y_train = mms.fit_transform(y_train.reshape(-1,1))

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
# Out:
# Using TensorFlow backend.

# %%
regressor = Sequential()
regressor.add(Dense(units=512,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=256,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=256,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=128,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=1,activation='relu',kernel_initializer='uniform'))

# %%
regressor.compile(optimizer='adam',loss='mean_squared_error',metrics=['mean_squared_error'])

# %%
regressor.fit(X_train,y_train,epochs=100,batch_size=50)
# Out:
# Epoch 1/100
# 1460/1460 [==============================] - 0s 329us/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 2/100
# 1460/1460 [==============================] - 0s 89us/step - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 3/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 4/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 5/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 6/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 7/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 8/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 9/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 9.2810e-04 - mean_squared_error: 9.2810e-04
# Epoch 10/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 7.7844e-04 - mean_squared_error: 7.7844e-04
# Epoch 11/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 8.7973e-04 - mean_squared_error: 8.7973e-04
# Epoch 12/100
# 1460/1460 [==============================] - 0s 84us/step - loss: 5.9469e-04 - mean_squared_error: 5.9469e-04
# Epoch 13/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 5.0243e-04 - mean_squared_error: 5.0243e-04
# Epoch 14/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 5.0888e-04 - mean_squared_error: 5.0888e-04
# Epoch 15/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.3855e-04 - mean_squared_error: 4.3855e-04
# Epoch 16/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 3.9887e-04 - mean_squared_error: 3.9887e-04
# Epoch 17/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.1346e-04 - mean_squared_error: 4.1346e-04
# Epoch 18/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 3.7883e-04 - mean_squared_error: 3.7883e-04
# Epoch 19/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 3.2171e-04 - mean_squared_error: 3.2171e-04
# Epoch 20/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 5.8633e-04 - mean_squared_error: 5.8633e-04
# Epoch 21/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.9503e-04 - mean_squared_error: 4.9503e-04
# Epoch 22/100
# 1460/1460 [==============================] - 0s 89us/step - loss: 5.8650e-04 - mean_squared_error: 5.8650e-04
# Epoch 23/100
# 1460/1460 [==============================] - 0s 97us/step - loss: 3.1794e-04 - mean_squared_error: 3.1794e-04
# Epoch 24/100
# 1460/1460 [==============================] - 0s 101us/step - loss: 2.9213e-04 - mean_squared_error: 2.9212e-04
# Epoch 25/100
# 1460/1460 [==============================] - 0s 90us/step - loss: 2.4036e-04 - mean_squared_error: 2.4036e-04
# Epoch 26/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 2.3191e-04 - mean_squared_error: 2.3191e-04
# Epoch 27/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 1.8397e-04 - mean_squared_error: 1.8397e-04
# Epoch 28/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.9801e-04 - mean_squared_error: 1.9801e-04
# Epoch 29/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.5802e-04 - mean_squared_error: 1.5802e-04
# Epoch 30/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 1.4638e-04 - mean_squared_error: 1.4638e-04
# Epoch 31/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.3568e-04 - mean_squared_error: 1.3568e-04
# Epoch 32/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.0566e-04 - mean_squared_error: 1.0566e-04
# Epoch 33/100
# 1460/1460 [==============================] - 0s 89us/step - loss: 1.1470e-04 - mean_squared_error: 1.1470e-04
# Epoch 34/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 1.4084e-04 - mean_squared_error: 1.4084e-04
# Epoch 35/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 1.0101e-04 - mean_squared_error: 1.0101e-04
# Epoch 36/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.3322e-04 - mean_squared_error: 1.3322e-04
# Epoch 37/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.0571e-04 - mean_squared_error: 1.0571e-04
# Epoch 38/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.1412e-04 - mean_squared_error: 1.1412e-04
# Epoch 39/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.5529e-04 - mean_squared_error: 1.5529e-04
# Epoch 40/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 8.8795e-05 - mean_squared_error: 8.8795e-05
# Epoch 41/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 7.8248e-05 - mean_squared_error: 7.8248e-05
# Epoch 42/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.0065e-04 - mean_squared_error: 1.0065e-04
# Epoch 43/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.7161e-05 - mean_squared_error: 7.7161e-05
# Epoch 44/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.1358e-04 - mean_squared_error: 1.1358e-04
# Epoch 45/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.4046e-04 - mean_squared_error: 1.4046e-04
# Epoch 46/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 9.1393e-05 - mean_squared_error: 9.1393e-05
# Epoch 47/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 8.3902e-05 - mean_squared_error: 8.3902e-05
# Epoch 48/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.3480e-05 - mean_squared_error: 7.3480e-05
# Epoch 49/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.4331e-04 - mean_squared_error: 1.4331e-04
# Epoch 50/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.1254e-04 - mean_squared_error: 1.1254e-04
# Epoch 51/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 7.5093e-05 - mean_squared_error: 7.5093e-05
# Epoch 52/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 9.9426e-05 - mean_squared_error: 9.9426e-05
# Epoch 53/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.2484e-04 - mean_squared_error: 1.2484e-04
# Epoch 54/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.4267e-05 - mean_squared_error: 7.4267e-05
# Epoch 55/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 6.1732e-05 - mean_squared_error: 6.1732e-05
# Epoch 56/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 9.0292e-05 - mean_squared_error: 9.0292e-05
# Epoch 57/100
# 1460/1460 [==============================] - 0s 85us/step - loss: 1.6910e-04 - mean_squared_error: 1.6910e-04
# Epoch 58/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.3582e-04 - mean_squared_error: 1.3582e-04
# Epoch 59/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 6.2464e-05 - mean_squared_error: 6.2464e-05
# Epoch 60/100
# 1460/1460 [==============================] - 0s 92us/step - loss: 6.5335e-05 - mean_squared_error: 6.5335e-05
# Epoch 61/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 5.5569e-05 - mean_squared_error: 5.5569e-05
# Epoch 62/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 5.7841e-05 - mean_squared_error: 5.7841e-05
# Epoch 63/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.2918e-05 - mean_squared_error: 4.2918e-05
# Epoch 64/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 5.4078e-05 - mean_squared_error: 5.4078e-05
# Epoch 65/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.3589e-05 - mean_squared_error: 4.3589e-05
# Epoch 66/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 2.9228e-05 - mean_squared_error: 2.9228e-05
# Epoch 67/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 2.9086e-05 - mean_squared_error: 2.9086e-05
# Epoch 68/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 2.3455e-05 - mean_squared_error: 2.3455e-05
# Epoch 69/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 2.6918e-05 - mean_squared_error: 2.6918e-05
# Epoch 70/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 3.2196e-05 - mean_squared_error: 3.2196e-05
# Epoch 71/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 5.1746e-05 - mean_squared_error: 5.1746e-05
# Epoch 72/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 6.6641e-05 - mean_squared_error: 6.6641e-05
# Epoch 73/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 2.1486e-04 - mean_squared_error: 2.1486e-04
# Epoch 74/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 1.4721e-04 - mean_squared_error: 1.4721e-04
# Epoch 75/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 9.4942e-05 - mean_squared_error: 9.4942e-05
# Epoch 76/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.0331e-04 - mean_squared_error: 1.0331e-04
# Epoch 77/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 8.5055e-05 - mean_squared_error: 8.5055e-05
# Epoch 78/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 6.5266e-05 - mean_squared_error: 6.5266e-05
# Epoch 79/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 7.4612e-05 - mean_squared_error: 7.4612e-05
# Epoch 80/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.0710e-05 - mean_squared_error: 7.0710e-05
# Epoch 81/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 8.8771e-05 - mean_squared_error: 8.8771e-05
# Epoch 82/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 2.4620e-04 - mean_squared_error: 2.4620e-04
# Epoch 83/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.3765e-04 - mean_squared_error: 1.3765e-04
# Epoch 84/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.1951e-05 - mean_squared_error: 7.1951e-05
# Epoch 85/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 7.5842e-05 - mean_squared_error: 7.5842e-05
# Epoch 86/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 1.0023e-04 - mean_squared_error: 1.0023e-04
# Epoch 87/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 1.5797e-04 - mean_squared_error: 1.5797e-04
# Epoch 88/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 7.0529e-05 - mean_squared_error: 7.0529e-05
# Epoch 89/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 5.9053e-05 - mean_squared_error: 5.9053e-05
# Epoch 90/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 1.4244e-04 - mean_squared_error: 1.4244e-04
# Epoch 91/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 1.0137e-04 - mean_squared_error: 1.0137e-04
# Epoch 92/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 5.0860e-05 - mean_squared_error: 5.0860e-05
# Epoch 93/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 3.4863e-05 - mean_squared_error: 3.4863e-05
# Epoch 94/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 2.8480e-05 - mean_squared_error: 2.8480e-05
# Epoch 95/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 2.7882e-05 - mean_squared_error: 2.7882e-05
# Epoch 96/100
# 1460/1460 [==============================] - 0s 87us/step - loss: 2.0887e-05 - mean_squared_error: 2.0887e-05
# Epoch 97/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 2.0266e-05 - mean_squared_error: 2.0266e-05
# Epoch 98/100
# 1460/1460 [==============================] - 0s 86us/step - loss: 4.1365e-05 - mean_squared_error: 4.1365e-05
# Epoch 99/100
# 1460/1460 [==============================] - 0s 89us/step - loss: 5.8201e-05 - mean_squared_error: 5.8201e-05
# Epoch 100/100
# 1460/1460 [==============================] - 0s 88us/step - loss: 5.7233e-05 - mean_squared_error: 5.7233e-05

# %%
losses = regressor.history.history
losses = np.array(pd.DataFrame(losses))
plt.plot(losses)
plt.xlabel('Epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## Tuning the ANN

# %% [markdown]
# Commenting the code for timing constraint

# %%
'''
def build_classifier(optimizer,units1,units2,units3,units4):
    regressor = Sequential()
    regressor.add(Dense(units=units1,activation='relu',kernel_initializer='uniform'))
    regressor.add(Dense(units=units2,activation='relu',kernel_initializer='uniform'))
    regressor.add(Dense(units=units3,activation='relu',kernel_initializer='uniform'))
    regressor.add(Dense(units=units4,activation='relu',kernel_initializer='uniform'))
    regressor.add(Dense(units=1,activation='relu',kernel_initializer='uniform'))
    regressor.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])
    return regressor

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

regressor = KerasRegressor(build_fn=build_classifier)
parameters = {'batch_size':[10,15,25,32],
             'epochs':[100,300,500],
             'optimizer':['adam','rmsprop'],
             'units1':[512,256],
             'units2':[256,128],
             'units3':[256,128],
             'units4':[256,128,64]}

grid_search = GridSearchCV(estimator = regressor,
                           param_grid = parameters,
                           scoring = 'neg_mean_squared_error',
                           cv = 3)
grid_search = grid_search.fit(X_train, y_train)
'''
# Out:
# "\ndef build_classifier(optimizer,units1,units2,units3,units4):\n    regressor = Sequential()\n    regressor.add(Dense(units=units1,activation='relu',kernel_initializer='uniform'))\n    regressor.add(Dense(units=units2,activation='relu',kernel_initializer='uniform'))\n    regressor.add(Dense(units=units3,activation='relu',kernel_initializer='uniform'))\n    regressor.add(Dense(units=units4,activation='relu',kernel_initializer='uniform'))\n    regressor.add(Dense(units=1,activation='relu',kernel_initializer='uniform'))\n    regressor.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_squared_error'])\n    return regressor\n\nfrom keras.wrappers.scikit_learn import KerasRegressor\nfrom sklearn.model_selection import GridSearchCV\n\nregressor = KerasRegressor(build_fn=build_classifier)\nparameters = {'batch_size':[10,15,25,32],\n             'epochs':[100,300,500],\n             'optimizer':['adam','rmsprop'],\n             'units1':[512,256],\n             'units2':[256,128],\n             'units3':[256,128],\n             'units4':[256,128,64]}\n\ngrid_search = GridSearchCV(estimator = regressor,\n                           param_grid = parameters,\n                           scoring = 'neg_mean_squared_error',\n                           cv = 3)\ngrid_search = grid_search.fit(X_train, y_train)\n"

# %%
'''print(grid_search.best_score_)
print('\n')
print(grid_search.best_params_)'''
# Out:
# "print(grid_search.best_score_)\nprint('\n')\nprint(grid_search.best_params_)"

# %%
Best = {'batch_size': 15, 'epochs': 500, 'optimizer': 'adam', 'units1': 512, 'units2': 128, 'units3': 128, 'units4': 64}

# %%
#from keras.models import load_model
#regressor.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
#del model  # deletes the existing model
# returns a compiled model
# identical to the previous one
#regressor1 = load_model('my_model.h5')

# %% [markdown]
# ## Training the ANN on best parameters

# %%
regressor = Sequential()
regressor.add(Dense(units=512,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=256,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=256,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=128,activation='relu',kernel_initializer='uniform'))
regressor.add(Dense(units=1,activation='relu',kernel_initializer='uniform'))
regressor.compile(optimizer='adam',loss='mean_squared_error',metrics=['mean_squared_error'])

# %% [markdown]
# For furthur fine tuning add dropout layers and more layers to the model

# %%
regressor.fit(X_train,y_train,epochs=500,batch_size=15)
# Out:
# Epoch 1/500
# 1460/1460 [==============================] - 1s 359us/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 2/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 3/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 4/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 5/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 6/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 7/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 8/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 9.0591e-04 - mean_squared_error: 9.0591e-04
# Epoch 9/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.6528e-04 - mean_squared_error: 6.6528e-04
# Epoch 10/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 6.9416e-04 - mean_squared_error: 6.9416e-04
# Epoch 11/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 5.7215e-04 - mean_squared_error: 5.7215e-04
# Epoch 12/500
# 1460/1460 [==============================] - 0s 264us/step - loss: 4.4326e-04 - mean_squared_error: 4.4326e-04
# Epoch 13/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 4.4048e-04 - mean_squared_error: 4.4048e-04
# Epoch 14/500
# 1460/1460 [==============================] - 0s 225us/step - loss: 4.4917e-04 - mean_squared_error: 4.4917e-04
# Epoch 15/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 4.6001e-04 - mean_squared_error: 4.6001e-04
# Epoch 16/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 6.3382e-04 - mean_squared_error: 6.3382e-04
# Epoch 17/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 4.7767e-04 - mean_squared_error: 4.7767e-04
# Epoch 18/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.7378e-04 - mean_squared_error: 3.7378e-04
# Epoch 19/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.9741e-04 - mean_squared_error: 4.9741e-04
# Epoch 20/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 3.9632e-04 - mean_squared_error: 3.9632e-04
# Epoch 21/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.4622e-04 - mean_squared_error: 3.4622e-04
# Epoch 22/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.7237e-04 - mean_squared_error: 2.7237e-04
# Epoch 23/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 3.7068e-04 - mean_squared_error: 3.7068e-04
# Epoch 24/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.5374e-04 - mean_squared_error: 2.5374e-04
# Epoch 25/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.3750e-04 - mean_squared_error: 3.3750e-04
# Epoch 26/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.4858e-04 - mean_squared_error: 4.4858e-04
# Epoch 27/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 2.5676e-04 - mean_squared_error: 2.5676e-04
# Epoch 28/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.6276e-04 - mean_squared_error: 2.6276e-04
# Epoch 29/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 4.2586e-04 - mean_squared_error: 4.2586e-04
# Epoch 30/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 4.2705e-04 - mean_squared_error: 4.2705e-04
# Epoch 31/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 3.1818e-04 - mean_squared_error: 3.1818e-04
# Epoch 32/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.5486e-04 - mean_squared_error: 2.5486e-04
# Epoch 33/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 3.4000e-04 - mean_squared_error: 3.4000e-04
# Epoch 34/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.8750e-04 - mean_squared_error: 2.8750e-04
# Epoch 35/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.3906e-04 - mean_squared_error: 3.3906e-04
# Epoch 36/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.5925e-04 - mean_squared_error: 1.5925e-04
# Epoch 37/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.0630e-04 - mean_squared_error: 2.0630e-04
# Epoch 38/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 2.1514e-04 - mean_squared_error: 2.1514e-04
# Epoch 39/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 2.1398e-04 - mean_squared_error: 2.1398e-04
# Epoch 40/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 1.2181e-04 - mean_squared_error: 1.2181e-04
# Epoch 41/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.1122e-04 - mean_squared_error: 1.1122e-04
# Epoch 42/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.3328e-04 - mean_squared_error: 1.3328e-04
# Epoch 43/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.4425e-04 - mean_squared_error: 1.4425e-04
# Epoch 44/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.2040e-04 - mean_squared_error: 1.2040e-04
# Epoch 45/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.1816e-04 - mean_squared_error: 1.1816e-04
# Epoch 46/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 2.1420e-04 - mean_squared_error: 2.1420e-04
# Epoch 47/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.7020e-04 - mean_squared_error: 2.7020e-04
# Epoch 48/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.8405e-04 - mean_squared_error: 1.8405e-04
# Epoch 49/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.6277e-04 - mean_squared_error: 1.6277e-04
# Epoch 50/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.1914e-04 - mean_squared_error: 1.1914e-04
# Epoch 51/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0693e-04 - mean_squared_error: 1.0693e-04
# Epoch 52/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0594e-04 - mean_squared_error: 1.0594e-04
# Epoch 53/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.9936e-04 - mean_squared_error: 1.9936e-04
# Epoch 54/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.2069e-04 - mean_squared_error: 2.2069e-04
# Epoch 55/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 3.2722e-04 - mean_squared_error: 3.2722e-04
# Epoch 56/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.8613e-04 - mean_squared_error: 2.8613e-04
# Epoch 57/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.1672e-04 - mean_squared_error: 2.1672e-04
# Epoch 58/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.8344e-04 - mean_squared_error: 2.8344e-04
# Epoch 59/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.8481e-04 - mean_squared_error: 1.8481e-04
# Epoch 60/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 1.8213e-04 - mean_squared_error: 1.8213e-04
# Epoch 61/500
# 1460/1460 [==============================] - 0s 248us/step - loss: 1.1370e-04 - mean_squared_error: 1.1370e-04
# Epoch 62/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 8.0932e-05 - mean_squared_error: 8.0932e-05
# Epoch 63/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 7.7002e-05 - mean_squared_error: 7.7002e-05
# Epoch 64/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 7.9391e-05 - mean_squared_error: 7.9391e-05
# Epoch 65/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 6.8134e-05 - mean_squared_error: 6.8134e-05
# Epoch 66/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 9.8791e-05 - mean_squared_error: 9.8791e-05
# Epoch 67/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 7.9260e-05 - mean_squared_error: 7.9260e-05
# Epoch 68/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 5.8496e-05 - mean_squared_error: 5.8496e-05
# Epoch 69/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.2760e-04 - mean_squared_error: 1.2760e-04
# Epoch 70/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.2232e-04 - mean_squared_error: 1.2232e-04
# Epoch 71/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.3051e-04 - mean_squared_error: 2.3051e-04
# Epoch 72/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.7385e-04 - mean_squared_error: 2.7385e-04
# Epoch 73/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.6996e-04 - mean_squared_error: 2.6996e-04
# Epoch 74/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.8410e-04 - mean_squared_error: 1.8410e-04
# Epoch 75/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.6246e-04 - mean_squared_error: 1.6246e-04
# Epoch 76/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 9.8508e-05 - mean_squared_error: 9.8508e-05
# Epoch 77/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 6.0740e-05 - mean_squared_error: 6.0740e-05
# Epoch 78/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.4530e-05 - mean_squared_error: 4.4530e-05
# Epoch 79/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 9.9872e-05 - mean_squared_error: 9.9872e-05
# Epoch 80/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0206e-04 - mean_squared_error: 1.0206e-04
# Epoch 81/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.0332e-04 - mean_squared_error: 2.0332e-04
# Epoch 82/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.0991e-04 - mean_squared_error: 1.0991e-04
# Epoch 83/500
# 1460/1460 [==============================] - 0s 225us/step - loss: 1.3771e-04 - mean_squared_error: 1.3771e-04
# Epoch 84/500
# 1460/1460 [==============================] - 0s 331us/step - loss: 5.1814e-05 - mean_squared_error: 5.1814e-05
# Epoch 85/500
# 1460/1460 [==============================] - 0s 265us/step - loss: 5.2795e-05 - mean_squared_error: 5.2795e-05
# Epoch 86/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 4.8316e-05 - mean_squared_error: 4.8316e-05
# Epoch 87/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.7993e-05 - mean_squared_error: 8.7993e-05
# Epoch 88/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 7.5878e-05 - mean_squared_error: 7.5878e-05
# Epoch 89/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 6.4160e-05 - mean_squared_error: 6.4160e-05
# Epoch 90/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 7.8897e-05 - mean_squared_error: 7.8897e-05
# Epoch 91/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 8.0579e-05 - mean_squared_error: 8.0579e-05
# Epoch 92/500
# 1460/1460 [==============================] - 0s 250us/step - loss: 8.5318e-05 - mean_squared_error: 8.5318e-05
# Epoch 93/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 1.6155e-04 - mean_squared_error: 1.6155e-04
# Epoch 94/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 4.2333e-04 - mean_squared_error: 4.2333e-04
# Epoch 95/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 2.6319e-04 - mean_squared_error: 2.6319e-04
# Epoch 96/500
# 1460/1460 [==============================] - 0s 242us/step - loss: 2.7511e-04 - mean_squared_error: 2.7511e-04
# Epoch 97/500
# 1460/1460 [==============================] - 0s 280us/step - loss: 1.2884e-04 - mean_squared_error: 1.2884e-04
# Epoch 98/500
# 1460/1460 [==============================] - 0s 296us/step - loss: 7.0681e-05 - mean_squared_error: 7.0681e-05
# Epoch 99/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 6.5402e-05 - mean_squared_error: 6.5402e-05
# Epoch 100/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 3.2610e-05 - mean_squared_error: 3.2610e-05
# Epoch 101/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 3.0937e-05 - mean_squared_error: 3.0937e-05
# Epoch 102/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.6493e-05 - mean_squared_error: 2.6493e-05
# Epoch 103/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 3.4954e-05 - mean_squared_error: 3.4954e-05
# Epoch 104/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 6.2829e-05 - mean_squared_error: 6.2829e-05
# Epoch 105/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.1601e-05 - mean_squared_error: 4.1601e-05
# Epoch 106/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 4.7411e-05 - mean_squared_error: 4.7411e-05
# Epoch 107/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 4.4330e-05 - mean_squared_error: 4.4330e-05
# Epoch 108/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 9.5580e-05 - mean_squared_error: 9.5580e-05
# Epoch 109/500
# 1460/1460 [==============================] - 0s 272us/step - loss: 9.1160e-05 - mean_squared_error: 9.1160e-05
# Epoch 110/500
# 1460/1460 [==============================] - 0s 268us/step - loss: 3.8898e-05 - mean_squared_error: 3.8898e-05
# Epoch 111/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 5.8965e-05 - mean_squared_error: 5.8965e-05
# Epoch 112/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 5.8778e-05 - mean_squared_error: 5.8778e-05
# Epoch 113/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.6344e-04 - mean_squared_error: 1.6344e-04
# Epoch 114/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.0599e-04 - mean_squared_error: 1.0599e-04
# Epoch 115/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.6841e-05 - mean_squared_error: 6.6841e-05
# Epoch 116/500
# 1460/1460 [==============================] - 0s 253us/step - loss: 5.6334e-05 - mean_squared_error: 5.6334e-05
# Epoch 117/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.2977e-04 - mean_squared_error: 1.2977e-04
# Epoch 118/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 6.3430e-05 - mean_squared_error: 6.3430e-05
# Epoch 119/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.7931e-05 - mean_squared_error: 5.7931e-05
# Epoch 120/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.8013e-05 - mean_squared_error: 3.8013e-05
# Epoch 121/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 6.6431e-05 - mean_squared_error: 6.6431e-05
# Epoch 122/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.8421e-05 - mean_squared_error: 3.8421e-05
# Epoch 123/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.5433e-05 - mean_squared_error: 5.5433e-05
# Epoch 124/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 5.4145e-05 - mean_squared_error: 5.4145e-05
# Epoch 125/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.2805e-04 - mean_squared_error: 1.2805e-04
# Epoch 126/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 7.9546e-05 - mean_squared_error: 7.9546e-05
# Epoch 127/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.8087e-05 - mean_squared_error: 8.8087e-05
# Epoch 128/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 7.2478e-05 - mean_squared_error: 7.2478e-05
# Epoch 129/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 9.3955e-05 - mean_squared_error: 9.3955e-05
# Epoch 130/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.0955e-05 - mean_squared_error: 5.0955e-05
# Epoch 131/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 8.4534e-05 - mean_squared_error: 8.4534e-05
# Epoch 132/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.3664e-05 - mean_squared_error: 4.3664e-05
# Epoch 133/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.7222e-05 - mean_squared_error: 2.7222e-05
# Epoch 134/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.0829e-05 - mean_squared_error: 2.0829e-05
# Epoch 135/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.8177e-05 - mean_squared_error: 2.8177e-05
# Epoch 136/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.1904e-05 - mean_squared_error: 2.1904e-05
# Epoch 137/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.9972e-05 - mean_squared_error: 1.9972e-05
# Epoch 138/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.9076e-05 - mean_squared_error: 1.9076e-05
# Epoch 139/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.3960e-05 - mean_squared_error: 4.3960e-05
# Epoch 140/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 3.5310e-05 - mean_squared_error: 3.5310e-05
# Epoch 141/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.3330e-04 - mean_squared_error: 1.3330e-04
# Epoch 142/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.7560e-04 - mean_squared_error: 2.7560e-04
# Epoch 143/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.1157e-04 - mean_squared_error: 1.1157e-04
# Epoch 144/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 4.9816e-05 - mean_squared_error: 4.9816e-05
# Epoch 145/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.3818e-04 - mean_squared_error: 1.3818e-04
# Epoch 146/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.3502e-04 - mean_squared_error: 1.3502e-04
# Epoch 147/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.7352e-05 - mean_squared_error: 4.7352e-05
# Epoch 148/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 7.1692e-05 - mean_squared_error: 7.1692e-05
# Epoch 149/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 7.3928e-05 - mean_squared_error: 7.3928e-05
# Epoch 150/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 4.6142e-05 - mean_squared_error: 4.6142e-05
# Epoch 151/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.2336e-05 - mean_squared_error: 2.2336e-05
# Epoch 152/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.6268e-05 - mean_squared_error: 1.6268e-05
# Epoch 153/500
# 1460/1460 [==============================] - 0s 241us/step - loss: 1.2387e-05 - mean_squared_error: 1.2387e-05
# Epoch 154/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 1.2547e-05 - mean_squared_error: 1.2547e-05
# Epoch 155/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.0240e-05 - mean_squared_error: 1.0240e-05
# Epoch 156/500
# 1460/1460 [==============================] - 0s 261us/step - loss: 2.0331e-05 - mean_squared_error: 2.0331e-05
# Epoch 157/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 2.9403e-05 - mean_squared_error: 2.9403e-05
# Epoch 158/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 4.5218e-05 - mean_squared_error: 4.5218e-05
# Epoch 159/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.1664e-04 - mean_squared_error: 1.1664e-04
# Epoch 160/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 6.0358e-05 - mean_squared_error: 6.0358e-05
# Epoch 161/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.0333e-05 - mean_squared_error: 6.0333e-05
# Epoch 162/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.5062e-05 - mean_squared_error: 5.5062e-05
# Epoch 163/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.9056e-05 - mean_squared_error: 4.9056e-05
# Epoch 164/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.0364e-05 - mean_squared_error: 4.0364e-05
# Epoch 165/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.9192e-05 - mean_squared_error: 2.9192e-05
# Epoch 166/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 5.0447e-05 - mean_squared_error: 5.0447e-05
# Epoch 167/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.1601e-04 - mean_squared_error: 1.1601e-04
# Epoch 168/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 5.7680e-05 - mean_squared_error: 5.7680e-05
# Epoch 169/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 4.2949e-05 - mean_squared_error: 4.2949e-05
# Epoch 170/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.3379e-05 - mean_squared_error: 3.3379e-05
# Epoch 171/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.7833e-05 - mean_squared_error: 1.7833e-05
# Epoch 172/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.1617e-05 - mean_squared_error: 3.1617e-05
# Epoch 173/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.8823e-05 - mean_squared_error: 1.8823e-05
# Epoch 174/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.0046e-05 - mean_squared_error: 2.0046e-05
# Epoch 175/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 2.3631e-05 - mean_squared_error: 2.3631e-05
# Epoch 176/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.8265e-05 - mean_squared_error: 1.8265e-05
# Epoch 177/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.6013e-05 - mean_squared_error: 4.6013e-05
# Epoch 178/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 2.6195e-04 - mean_squared_error: 2.6195e-04
# Epoch 179/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.3907e-04 - mean_squared_error: 1.3907e-04
# Epoch 180/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 5.3153e-05 - mean_squared_error: 5.3153e-05
# Epoch 181/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.6422e-05 - mean_squared_error: 2.6422e-05
# Epoch 182/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.8162e-05 - mean_squared_error: 1.8162e-05
# Epoch 183/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.9696e-05 - mean_squared_error: 1.9696e-05
# Epoch 184/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.6753e-05 - mean_squared_error: 1.6753e-05
# Epoch 185/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.7470e-05 - mean_squared_error: 1.7470e-05
# Epoch 186/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.3309e-05 - mean_squared_error: 3.3309e-05
# Epoch 187/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.7701e-05 - mean_squared_error: 2.7701e-05
# Epoch 188/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.2624e-05 - mean_squared_error: 2.2624e-05
# Epoch 189/500
# 1460/1460 [==============================] - 0s 258us/step - loss: 2.0165e-05 - mean_squared_error: 2.0165e-05
# Epoch 190/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 2.2329e-05 - mean_squared_error: 2.2329e-05
# Epoch 191/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.8039e-05 - mean_squared_error: 1.8039e-05
# Epoch 192/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.5967e-05 - mean_squared_error: 1.5967e-05
# Epoch 193/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.9374e-05 - mean_squared_error: 1.9374e-05
# Epoch 194/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.7650e-05 - mean_squared_error: 6.7650e-05
# Epoch 195/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 7.9705e-05 - mean_squared_error: 7.9705e-05
# Epoch 196/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 7.1472e-05 - mean_squared_error: 7.1472e-05
# Epoch 197/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.8161e-05 - mean_squared_error: 4.8162e-05
# Epoch 198/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.5217e-05 - mean_squared_error: 3.5217e-05
# Epoch 199/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.5010e-05 - mean_squared_error: 3.5010e-05
# Epoch 200/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.0059e-05 - mean_squared_error: 4.0059e-05
# Epoch 201/500
# 1460/1460 [==============================] - 0s 341us/step - loss: 2.4645e-05 - mean_squared_error: 2.4645e-05
# Epoch 202/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 2.3641e-05 - mean_squared_error: 2.3641e-05
# Epoch 203/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.3590e-05 - mean_squared_error: 4.3590e-05
# Epoch 204/500
# 1460/1460 [==============================] - 0s 248us/step - loss: 3.7917e-05 - mean_squared_error: 3.7917e-05
# Epoch 205/500
# 1460/1460 [==============================] - 0s 265us/step - loss: 5.3650e-05 - mean_squared_error: 5.3650e-05
# Epoch 206/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.4272e-04 - mean_squared_error: 1.4272e-04
# Epoch 207/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.3324e-05 - mean_squared_error: 5.3324e-05
# Epoch 208/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.6688e-05 - mean_squared_error: 3.6688e-05
# Epoch 209/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.1858e-05 - mean_squared_error: 8.1858e-05
# Epoch 210/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.9033e-05 - mean_squared_error: 8.9033e-05
# Epoch 211/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.4544e-04 - mean_squared_error: 1.4544e-04
# Epoch 212/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.6373e-05 - mean_squared_error: 5.6373e-05
# Epoch 213/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 2.6399e-05 - mean_squared_error: 2.6399e-05
# Epoch 214/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.6906e-05 - mean_squared_error: 1.6906e-05
# Epoch 215/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0728e-05 - mean_squared_error: 1.0728e-05
# Epoch 216/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 9.6862e-06 - mean_squared_error: 9.6862e-06
# Epoch 217/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 7.8846e-06 - mean_squared_error: 7.8846e-06
# Epoch 218/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 5.7876e-06 - mean_squared_error: 5.7876e-06
# Epoch 219/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.5263e-06 - mean_squared_error: 6.5263e-06
# Epoch 220/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 1.0375e-05 - mean_squared_error: 1.0375e-05
# Epoch 221/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.6778e-05 - mean_squared_error: 1.6778e-05
# Epoch 222/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.3814e-05 - mean_squared_error: 1.3814e-05
# Epoch 223/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 5.8765e-05 - mean_squared_error: 5.8765e-05
# Epoch 224/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.5241e-05 - mean_squared_error: 4.5241e-05
# Epoch 225/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.3070e-05 - mean_squared_error: 4.3070e-05
# Epoch 226/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.6283e-05 - mean_squared_error: 4.6283e-05
# Epoch 227/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.2401e-05 - mean_squared_error: 3.2401e-05
# Epoch 228/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 7.7276e-05 - mean_squared_error: 7.7276e-05
# Epoch 229/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 5.0233e-05 - mean_squared_error: 5.0233e-05
# Epoch 230/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.0480e-05 - mean_squared_error: 2.0480e-05
# Epoch 231/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.3170e-05 - mean_squared_error: 1.3170e-05
# Epoch 232/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.5495e-05 - mean_squared_error: 1.5495e-05
# Epoch 233/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.4951e-05 - mean_squared_error: 1.4951e-05
# Epoch 234/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.9231e-05 - mean_squared_error: 2.9231e-05
# Epoch 235/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.2848e-05 - mean_squared_error: 3.2848e-05
# Epoch 236/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.7720e-05 - mean_squared_error: 1.7720e-05
# Epoch 237/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.6792e-05 - mean_squared_error: 1.6792e-05
# Epoch 238/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.8364e-05 - mean_squared_error: 1.8364e-05
# Epoch 239/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.6962e-05 - mean_squared_error: 1.6962e-05
# Epoch 240/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 3.0423e-05 - mean_squared_error: 3.0423e-05
# Epoch 241/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.2234e-05 - mean_squared_error: 5.2234e-05
# Epoch 242/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 9.4128e-05 - mean_squared_error: 9.4128e-05
# Epoch 243/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 4.4781e-05 - mean_squared_error: 4.4782e-05
# Epoch 244/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 5.8742e-05 - mean_squared_error: 5.8742e-05
# Epoch 245/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.5568e-05 - mean_squared_error: 2.5568e-05
# Epoch 246/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.7457e-05 - mean_squared_error: 2.7457e-05
# Epoch 247/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.2464e-05 - mean_squared_error: 4.2464e-05
# Epoch 248/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.7752e-05 - mean_squared_error: 2.7752e-05
# Epoch 249/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 9.2088e-05 - mean_squared_error: 9.2088e-05
# Epoch 250/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 6.8543e-05 - mean_squared_error: 6.8543e-05
# Epoch 251/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.3566e-05 - mean_squared_error: 4.3566e-05
# Epoch 252/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 9.0060e-05 - mean_squared_error: 9.0060e-05
# Epoch 253/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 3.0220e-05 - mean_squared_error: 3.0220e-05
# Epoch 254/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 5.6171e-05 - mean_squared_error: 5.6171e-05
# Epoch 255/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.7047e-05 - mean_squared_error: 2.7047e-05
# Epoch 256/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.5268e-05 - mean_squared_error: 1.5268e-05
# Epoch 257/500
# 1460/1460 [==============================] - 0s 293us/step - loss: 9.7217e-06 - mean_squared_error: 9.7217e-06
# Epoch 258/500
# 1460/1460 [==============================] - 0s 283us/step - loss: 8.3836e-06 - mean_squared_error: 8.3836e-06
# Epoch 259/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 7.4451e-06 - mean_squared_error: 7.4451e-06
# Epoch 260/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 7.8628e-06 - mean_squared_error: 7.8628e-06
# Epoch 261/500
# 1460/1460 [==============================] - 0s 278us/step - loss: 5.2649e-06 - mean_squared_error: 5.2649e-06
# Epoch 262/500
# 1460/1460 [==============================] - 0s 244us/step - loss: 8.9693e-06 - mean_squared_error: 8.9693e-06
# Epoch 263/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 1.4848e-05 - mean_squared_error: 1.4848e-05
# Epoch 264/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.1442e-05 - mean_squared_error: 2.1442e-05
# Epoch 265/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 3.0295e-05 - mean_squared_error: 3.0295e-05
# Epoch 266/500
# 1460/1460 [==============================] - 0s 246us/step - loss: 1.9362e-05 - mean_squared_error: 1.9362e-05
# Epoch 267/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.7718e-05 - mean_squared_error: 2.7718e-05
# Epoch 268/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.0032e-05 - mean_squared_error: 2.0032e-05
# Epoch 269/500
# 1460/1460 [==============================] - 0s 241us/step - loss: 2.4426e-05 - mean_squared_error: 2.4426e-05
# Epoch 270/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.5705e-05 - mean_squared_error: 2.5705e-05
# Epoch 271/500
# 1460/1460 [==============================] - 0s 250us/step - loss: 3.0941e-05 - mean_squared_error: 3.0941e-05
# Epoch 272/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 2.6797e-05 - mean_squared_error: 2.6797e-05
# Epoch 273/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 2.8272e-05 - mean_squared_error: 2.8272e-05
# Epoch 274/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 6.1649e-05 - mean_squared_error: 6.1649e-05
# Epoch 275/500
# 1460/1460 [==============================] - 0s 240us/step - loss: 1.0019e-04 - mean_squared_error: 1.0019e-04
# Epoch 276/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 5.2409e-05 - mean_squared_error: 5.2409e-05
# Epoch 277/500
# 1460/1460 [==============================] - 0s 254us/step - loss: 3.2625e-05 - mean_squared_error: 3.2625e-05
# Epoch 278/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 6.2339e-05 - mean_squared_error: 6.2339e-05
# Epoch 279/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 2.6516e-05 - mean_squared_error: 2.6516e-05
# Epoch 280/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.4044e-05 - mean_squared_error: 2.4044e-05
# Epoch 281/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.3143e-05 - mean_squared_error: 1.3143e-05
# Epoch 282/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.2108e-05 - mean_squared_error: 1.2108e-05
# Epoch 283/500
# 1460/1460 [==============================] - 0s 245us/step - loss: 9.1239e-06 - mean_squared_error: 9.1239e-06
# Epoch 284/500
# 1460/1460 [==============================] - 0s 253us/step - loss: 8.7938e-06 - mean_squared_error: 8.7938e-06
# Epoch 285/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.0321e-05 - mean_squared_error: 2.0321e-05
# Epoch 286/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.4583e-05 - mean_squared_error: 1.4583e-05
# Epoch 287/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.3100e-05 - mean_squared_error: 1.3100e-05
# Epoch 288/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.3846e-05 - mean_squared_error: 1.3846e-05
# Epoch 289/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.1451e-05 - mean_squared_error: 4.1451e-05
# Epoch 290/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.7213e-05 - mean_squared_error: 4.7213e-05
# Epoch 291/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 5.1088e-05 - mean_squared_error: 5.1088e-05
# Epoch 292/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.5762e-04 - mean_squared_error: 1.5762e-04
# Epoch 293/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.2258e-04 - mean_squared_error: 1.2258e-04
# Epoch 294/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 7.5262e-05 - mean_squared_error: 7.5262e-05
# Epoch 295/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 2.0827e-05 - mean_squared_error: 2.0827e-05
# Epoch 296/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0559e-05 - mean_squared_error: 1.0559e-05
# Epoch 297/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.5577e-06 - mean_squared_error: 6.5577e-06
# Epoch 298/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 7.8590e-06 - mean_squared_error: 7.8590e-06
# Epoch 299/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.5823e-05 - mean_squared_error: 1.5823e-05
# Epoch 300/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 7.0541e-06 - mean_squared_error: 7.0541e-06
# Epoch 301/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 5.7388e-06 - mean_squared_error: 5.7388e-06
# Epoch 302/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.9176e-06 - mean_squared_error: 4.9176e-06
# Epoch 303/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.9825e-05 - mean_squared_error: 1.9825e-05
# Epoch 304/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 1.8301e-05 - mean_squared_error: 1.8301e-05
# Epoch 305/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 2.8084e-05 - mean_squared_error: 2.8084e-05
# Epoch 306/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.6001e-05 - mean_squared_error: 1.6001e-05
# Epoch 307/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.6305e-05 - mean_squared_error: 1.6305e-05
# Epoch 308/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 5.6848e-05 - mean_squared_error: 5.6848e-05
# Epoch 309/500
# 1460/1460 [==============================] - 0s 248us/step - loss: 4.1076e-05 - mean_squared_error: 4.1076e-05
# Epoch 310/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 1.9399e-05 - mean_squared_error: 1.9399e-05
# Epoch 311/500
# 1460/1460 [==============================] - 0s 253us/step - loss: 1.9748e-05 - mean_squared_error: 1.9748e-05
# Epoch 312/500
# 1460/1460 [==============================] - 0s 255us/step - loss: 2.8541e-05 - mean_squared_error: 2.8541e-05
# Epoch 313/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 1.9302e-05 - mean_squared_error: 1.9302e-05
# Epoch 314/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 9.5900e-06 - mean_squared_error: 9.5900e-06
# Epoch 315/500
# 1460/1460 [==============================] - 0s 277us/step - loss: 1.6942e-05 - mean_squared_error: 1.6942e-05
# Epoch 316/500
# 1460/1460 [==============================] - 0s 254us/step - loss: 7.9209e-05 - mean_squared_error: 7.9209e-05
# Epoch 317/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 6.4416e-05 - mean_squared_error: 6.4416e-05
# Epoch 318/500
# 1460/1460 [==============================] - 0s 262us/step - loss: 2.3354e-05 - mean_squared_error: 2.3354e-05
# Epoch 319/500
# 1460/1460 [==============================] - 0s 257us/step - loss: 3.9831e-05 - mean_squared_error: 3.9831e-05
# Epoch 320/500
# 1460/1460 [==============================] - 0s 255us/step - loss: 1.7405e-05 - mean_squared_error: 1.7405e-05
# Epoch 321/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 1.7102e-05 - mean_squared_error: 1.7102e-05
# Epoch 322/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 9.1585e-06 - mean_squared_error: 9.1585e-06
# Epoch 323/500
# 1460/1460 [==============================] - 0s 254us/step - loss: 1.1068e-05 - mean_squared_error: 1.1068e-05
# Epoch 324/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 1.2104e-05 - mean_squared_error: 1.2104e-05
# Epoch 325/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 1.0217e-05 - mean_squared_error: 1.0217e-05
# Epoch 326/500
# 1460/1460 [==============================] - 0s 254us/step - loss: 8.8331e-06 - mean_squared_error: 8.8331e-06
# Epoch 327/500
# 1460/1460 [==============================] - 0s 259us/step - loss: 8.6272e-06 - mean_squared_error: 8.6272e-06
# Epoch 328/500
# 1460/1460 [==============================] - 0s 257us/step - loss: 1.0270e-05 - mean_squared_error: 1.0270e-05
# Epoch 329/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 5.1474e-05 - mean_squared_error: 5.1474e-05
# Epoch 330/500
# 1460/1460 [==============================] - 0s 260us/step - loss: 3.4841e-05 - mean_squared_error: 3.4841e-05
# Epoch 331/500
# 1460/1460 [==============================] - 0s 257us/step - loss: 8.5729e-05 - mean_squared_error: 8.5729e-05
# Epoch 332/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 4.1533e-05 - mean_squared_error: 4.1533e-05
# Epoch 333/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 5.7525e-05 - mean_squared_error: 5.7525e-05
# Epoch 334/500
# 1460/1460 [==============================] - 0s 253us/step - loss: 6.5419e-05 - mean_squared_error: 6.5419e-05
# Epoch 335/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 4.9833e-05 - mean_squared_error: 4.9833e-05
# Epoch 336/500
# 1460/1460 [==============================] - 0s 241us/step - loss: 2.2281e-05 - mean_squared_error: 2.2281e-05
# Epoch 337/500
# 1460/1460 [==============================] - 0s 226us/step - loss: 3.2914e-05 - mean_squared_error: 3.2914e-05
# Epoch 338/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.4771e-05 - mean_squared_error: 1.4771e-05
# Epoch 339/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.1014e-05 - mean_squared_error: 1.1014e-05
# Epoch 340/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 8.7370e-06 - mean_squared_error: 8.7370e-06
# Epoch 341/500
# 1460/1460 [==============================] - 0s 226us/step - loss: 5.7016e-06 - mean_squared_error: 5.7016e-06
# Epoch 342/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 4.1641e-06 - mean_squared_error: 4.1641e-06
# Epoch 343/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.7944e-06 - mean_squared_error: 3.7944e-06
# Epoch 344/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.5491e-06 - mean_squared_error: 3.5491e-06
# Epoch 345/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 7.1244e-06 - mean_squared_error: 7.1244e-06
# Epoch 346/500
# 1460/1460 [==============================] - 0s 255us/step - loss: 6.7197e-06 - mean_squared_error: 6.7197e-06
# Epoch 347/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0868e-05 - mean_squared_error: 1.0868e-05
# Epoch 348/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 8.6040e-05 - mean_squared_error: 8.6040e-05
# Epoch 349/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 6.6601e-05 - mean_squared_error: 6.6601e-05
# Epoch 350/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 3.5326e-05 - mean_squared_error: 3.5326e-05
# Epoch 351/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 4.8244e-05 - mean_squared_error: 4.8244e-05
# Epoch 352/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.6340e-05 - mean_squared_error: 5.6340e-05
# Epoch 353/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.1077e-05 - mean_squared_error: 3.1077e-05
# Epoch 354/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.2331e-05 - mean_squared_error: 1.2331e-05
# Epoch 355/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.0302e-05 - mean_squared_error: 1.0302e-05
# Epoch 356/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.0726e-05 - mean_squared_error: 1.0726e-05
# Epoch 357/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 9.1808e-06 - mean_squared_error: 9.1808e-06
# Epoch 358/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.6329e-05 - mean_squared_error: 1.6329e-05
# Epoch 359/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.4772e-06 - mean_squared_error: 8.4772e-06
# Epoch 360/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 6.6006e-06 - mean_squared_error: 6.6006e-06
# Epoch 361/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 7.0252e-06 - mean_squared_error: 7.0252e-06
# Epoch 362/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.9553e-06 - mean_squared_error: 4.9553e-06
# Epoch 363/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 9.5474e-06 - mean_squared_error: 9.5474e-06
# Epoch 364/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 8.7530e-06 - mean_squared_error: 8.7530e-06
# Epoch 365/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.7041e-05 - mean_squared_error: 1.7041e-05
# Epoch 366/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 5.1974e-05 - mean_squared_error: 5.1974e-05
# Epoch 367/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.9542e-05 - mean_squared_error: 4.9542e-05
# Epoch 368/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 4.0697e-05 - mean_squared_error: 4.0697e-05
# Epoch 369/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.6761e-05 - mean_squared_error: 1.6761e-05
# Epoch 370/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.1026e-05 - mean_squared_error: 1.1026e-05
# Epoch 371/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.0137e-05 - mean_squared_error: 1.0137e-05
# Epoch 372/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.2282e-05 - mean_squared_error: 2.2281e-05
# Epoch 373/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.6620e-05 - mean_squared_error: 2.6620e-05
# Epoch 374/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 1.7540e-05 - mean_squared_error: 1.7540e-05
# Epoch 375/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 8.0343e-05 - mean_squared_error: 8.0343e-05
# Epoch 376/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 5.7008e-05 - mean_squared_error: 5.7008e-05
# Epoch 377/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 3.2268e-05 - mean_squared_error: 3.2268e-05
# Epoch 378/500
# 1460/1460 [==============================] - 0s 253us/step - loss: 2.1829e-05 - mean_squared_error: 2.1829e-05
# Epoch 379/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 1.1356e-05 - mean_squared_error: 1.1356e-05
# Epoch 380/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.6499e-05 - mean_squared_error: 2.6499e-05
# Epoch 381/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 1.0466e-05 - mean_squared_error: 1.0466e-05
# Epoch 382/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.6916e-05 - mean_squared_error: 1.6916e-05
# Epoch 383/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 9.9139e-06 - mean_squared_error: 9.9139e-06
# Epoch 384/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.6605e-05 - mean_squared_error: 1.6605e-05
# Epoch 385/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.1092e-05 - mean_squared_error: 1.1092e-05
# Epoch 386/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 5.9958e-06 - mean_squared_error: 5.9958e-06
# Epoch 387/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.0219e-05 - mean_squared_error: 1.0219e-05
# Epoch 388/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 9.3960e-06 - mean_squared_error: 9.3960e-06
# Epoch 389/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 6.2664e-06 - mean_squared_error: 6.2664e-06
# Epoch 390/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 1.8161e-05 - mean_squared_error: 1.8161e-05
# Epoch 391/500
# 1460/1460 [==============================] - 0s 228us/step - loss: 3.5118e-05 - mean_squared_error: 3.5118e-05
# Epoch 392/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.5866e-05 - mean_squared_error: 3.5866e-05
# Epoch 393/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 4.8261e-05 - mean_squared_error: 4.8261e-05
# Epoch 394/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 3.8921e-05 - mean_squared_error: 3.8921e-05
# Epoch 395/500
# 1460/1460 [==============================] - 0s 268us/step - loss: 1.8010e-05 - mean_squared_error: 1.8010e-05
# Epoch 396/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.3219e-05 - mean_squared_error: 1.3219e-05
# Epoch 397/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.9938e-05 - mean_squared_error: 1.9938e-05
# Epoch 398/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.5297e-05 - mean_squared_error: 1.5297e-05
# Epoch 399/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.0832e-05 - mean_squared_error: 1.0832e-05
# Epoch 400/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.4633e-05 - mean_squared_error: 1.4633e-05
# Epoch 401/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.4078e-05 - mean_squared_error: 1.4078e-05
# Epoch 402/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 3.6297e-05 - mean_squared_error: 3.6297e-05
# Epoch 403/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 4.1692e-05 - mean_squared_error: 4.1692e-05
# Epoch 404/500
# 1460/1460 [==============================] - 0s 227us/step - loss: 3.2971e-05 - mean_squared_error: 3.2971e-05
# Epoch 405/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 6.8478e-05 - mean_squared_error: 6.8478e-05
# Epoch 406/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 8.7939e-05 - mean_squared_error: 8.7939e-05
# Epoch 407/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 6.4734e-05 - mean_squared_error: 6.4734e-05
# Epoch 408/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 4.6854e-05 - mean_squared_error: 4.6854e-05
# Epoch 409/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 2.1178e-05 - mean_squared_error: 2.1178e-05
# Epoch 410/500
# 1460/1460 [==============================] - 0s 256us/step - loss: 2.2400e-05 - mean_squared_error: 2.2400e-05
# Epoch 411/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.1884e-05 - mean_squared_error: 1.1884e-05
# Epoch 412/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 7.5528e-06 - mean_squared_error: 7.5528e-06
# Epoch 413/500
# 1460/1460 [==============================] - 0s 239us/step - loss: 4.0390e-06 - mean_squared_error: 4.0390e-06
# Epoch 414/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 3.4867e-06 - mean_squared_error: 3.4867e-06
# Epoch 415/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 3.4978e-06 - mean_squared_error: 3.4978e-06
# Epoch 416/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.9474e-06 - mean_squared_error: 2.9474e-06
# Epoch 417/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.0131e-06 - mean_squared_error: 2.0131e-06
# Epoch 418/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.1929e-06 - mean_squared_error: 2.1929e-06
# Epoch 419/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.9869e-06 - mean_squared_error: 1.9869e-06
# Epoch 420/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.2562e-06 - mean_squared_error: 3.2562e-06
# Epoch 421/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.2161e-05 - mean_squared_error: 1.2161e-05
# Epoch 422/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 8.6005e-06 - mean_squared_error: 8.6005e-06
# Epoch 423/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 8.2854e-06 - mean_squared_error: 8.2854e-06
# Epoch 424/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 8.5656e-06 - mean_squared_error: 8.5656e-06
# Epoch 425/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 3.2572e-05 - mean_squared_error: 3.2572e-05
# Epoch 426/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 2.7959e-05 - mean_squared_error: 2.7959e-05
# Epoch 427/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 6.3599e-05 - mean_squared_error: 6.3599e-05
# Epoch 428/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 2.8353e-05 - mean_squared_error: 2.8353e-05
# Epoch 429/500
# 1460/1460 [==============================] - 0s 306us/step - loss: 1.9109e-05 - mean_squared_error: 1.9109e-05
# Epoch 430/500
# 1460/1460 [==============================] - 0s 289us/step - loss: 2.0853e-05 - mean_squared_error: 2.0853e-05
# Epoch 431/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.0659e-05 - mean_squared_error: 1.0659e-05
# Epoch 432/500
# 1460/1460 [==============================] - 0s 250us/step - loss: 1.2683e-05 - mean_squared_error: 1.2683e-05
# Epoch 433/500
# 1460/1460 [==============================] - 0s 284us/step - loss: 7.0431e-06 - mean_squared_error: 7.0431e-06
# Epoch 434/500
# 1460/1460 [==============================] - 0s 247us/step - loss: 1.4160e-05 - mean_squared_error: 1.4160e-05
# Epoch 435/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 1.1674e-05 - mean_squared_error: 1.1674e-05
# Epoch 436/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 8.4481e-06 - mean_squared_error: 8.4481e-06
# Epoch 437/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.2893e-05 - mean_squared_error: 1.2893e-05
# Epoch 438/500
# 1460/1460 [==============================] - 0s 254us/step - loss: 1.3791e-05 - mean_squared_error: 1.3791e-05
# Epoch 439/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.8999e-05 - mean_squared_error: 1.8999e-05
# Epoch 440/500
# 1460/1460 [==============================] - 0s 229us/step - loss: 2.4528e-05 - mean_squared_error: 2.4528e-05
# Epoch 441/500
# 1460/1460 [==============================] - 0s 272us/step - loss: 3.0767e-05 - mean_squared_error: 3.0767e-05
# Epoch 442/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 2.1994e-05 - mean_squared_error: 2.1994e-05
# Epoch 443/500
# 1460/1460 [==============================] - 0s 247us/step - loss: 1.2843e-05 - mean_squared_error: 1.2843e-05
# Epoch 444/500
# 1460/1460 [==============================] - 0s 240us/step - loss: 1.6580e-05 - mean_squared_error: 1.6580e-05
# Epoch 445/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.4807e-05 - mean_squared_error: 1.4807e-05
# Epoch 446/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.7136e-05 - mean_squared_error: 1.7136e-05
# Epoch 447/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 1.7894e-05 - mean_squared_error: 1.7894e-05
# Epoch 448/500
# 1460/1460 [==============================] - 0s 257us/step - loss: 8.6832e-06 - mean_squared_error: 8.6832e-06
# Epoch 449/500
# 1460/1460 [==============================] - 0s 247us/step - loss: 9.7207e-06 - mean_squared_error: 9.7207e-06
# Epoch 450/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 1.7540e-05 - mean_squared_error: 1.7540e-05
# Epoch 451/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 2.4098e-05 - mean_squared_error: 2.4098e-05
# Epoch 452/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 2.1341e-05 - mean_squared_error: 2.1341e-05
# Epoch 453/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 4.4857e-05 - mean_squared_error: 4.4857e-05
# Epoch 454/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 6.0363e-05 - mean_squared_error: 6.0363e-05
# Epoch 455/500
# 1460/1460 [==============================] - 0s 251us/step - loss: 2.8484e-05 - mean_squared_error: 2.8484e-05
# Epoch 456/500
# 1460/1460 [==============================] - 0s 234us/step - loss: 4.3048e-05 - mean_squared_error: 4.3048e-05
# Epoch 457/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 2.4261e-05 - mean_squared_error: 2.4261e-05
# Epoch 458/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 7.5335e-06 - mean_squared_error: 7.5335e-06
# Epoch 459/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 6.1999e-06 - mean_squared_error: 6.1999e-06
# Epoch 460/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 4.4702e-06 - mean_squared_error: 4.4702e-06
# Epoch 461/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 2.4908e-06 - mean_squared_error: 2.4908e-06
# Epoch 462/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.9721e-06 - mean_squared_error: 1.9721e-06
# Epoch 463/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.9657e-06 - mean_squared_error: 1.9657e-06
# Epoch 464/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 4.5352e-06 - mean_squared_error: 4.5352e-06
# Epoch 465/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 7.3000e-06 - mean_squared_error: 7.3000e-06
# Epoch 466/500
# 1460/1460 [==============================] - 0s 248us/step - loss: 1.5235e-05 - mean_squared_error: 1.5235e-05
# Epoch 467/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 1.6019e-05 - mean_squared_error: 1.6019e-05
# Epoch 468/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.8468e-05 - mean_squared_error: 1.8468e-05
# Epoch 469/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 2.7852e-05 - mean_squared_error: 2.7852e-05
# Epoch 470/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 5.2964e-05 - mean_squared_error: 5.2964e-05
# Epoch 471/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 3.6606e-05 - mean_squared_error: 3.6606e-05
# Epoch 472/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.5006e-05 - mean_squared_error: 1.5006e-05
# Epoch 473/500
# 1460/1460 [==============================] - 0s 258us/step - loss: 8.9381e-06 - mean_squared_error: 8.9381e-06
# Epoch 474/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 5.4289e-06 - mean_squared_error: 5.4289e-06
# Epoch 475/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.7836e-05 - mean_squared_error: 1.7836e-05
# Epoch 476/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.6815e-05 - mean_squared_error: 1.6815e-05
# Epoch 477/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.3128e-05 - mean_squared_error: 1.3128e-05
# Epoch 478/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 1.0409e-05 - mean_squared_error: 1.0409e-05
# Epoch 479/500
# 1460/1460 [==============================] - 0s 232us/step - loss: 7.7454e-06 - mean_squared_error: 7.7454e-06
# Epoch 480/500
# 1460/1460 [==============================] - 0s 230us/step - loss: 1.8834e-05 - mean_squared_error: 1.8834e-05
# Epoch 481/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 1.6548e-05 - mean_squared_error: 1.6548e-05
# Epoch 482/500
# 1460/1460 [==============================] - 0s 231us/step - loss: 1.4969e-05 - mean_squared_error: 1.4969e-05
# Epoch 483/500
# 1460/1460 [==============================] - 0s 236us/step - loss: 1.1996e-05 - mean_squared_error: 1.1996e-05
# Epoch 484/500
# 1460/1460 [==============================] - 0s 252us/step - loss: 1.2964e-05 - mean_squared_error: 1.2964e-05
# Epoch 485/500
# 1460/1460 [==============================] - 0s 274us/step - loss: 2.7202e-05 - mean_squared_error: 2.7202e-05
# Epoch 486/500
# 1460/1460 [==============================] - 0s 244us/step - loss: 6.1853e-05 - mean_squared_error: 6.1853e-05
# Epoch 487/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 3.2303e-05 - mean_squared_error: 3.2303e-05
# Epoch 488/500
# 1460/1460 [==============================] - 0s 249us/step - loss: 2.0796e-05 - mean_squared_error: 2.0796e-05
# Epoch 489/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 2.7738e-05 - mean_squared_error: 2.7738e-05
# Epoch 490/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 1.6024e-05 - mean_squared_error: 1.6024e-05
# Epoch 491/500
# 1460/1460 [==============================] - 0s 243us/step - loss: 2.5225e-05 - mean_squared_error: 2.5225e-05
# Epoch 492/500
# 1460/1460 [==============================] - 0s 240us/step - loss: 4.1989e-05 - mean_squared_error: 4.1989e-05
# Epoch 493/500
# 1460/1460 [==============================] - 0s 245us/step - loss: 2.9820e-05 - mean_squared_error: 2.9820e-05
# Epoch 494/500
# 1460/1460 [==============================] - 0s 240us/step - loss: 1.0760e-05 - mean_squared_error: 1.0760e-05
# Epoch 495/500
# 1460/1460 [==============================] - 0s 238us/step - loss: 6.7827e-06 - mean_squared_error: 6.7827e-06
# Epoch 496/500
# 1460/1460 [==============================] - 0s 237us/step - loss: 3.3974e-06 - mean_squared_error: 3.3974e-06
# Epoch 497/500
# 1460/1460 [==============================] - 0s 240us/step - loss: 6.9250e-06 - mean_squared_error: 6.9250e-06
# Epoch 498/500
# 1460/1460 [==============================] - 0s 235us/step - loss: 4.1163e-06 - mean_squared_error: 4.1163e-06
# Epoch 499/500
# 1460/1460 [==============================] - 0s 233us/step - loss: 3.1431e-06 - mean_squared_error: 3.1431e-06
# Epoch 500/500
# 1460/1460 [==============================] - 0s 241us/step - loss: 9.3882e-06 - mean_squared_error: 9.3882e-06

# %%
losses = regressor.history.history
losses = np.array(pd.DataFrame(losses))
plt.plot(losses)
plt.xlabel('Epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
regressor.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               86016
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 316,161
# Trainable params: 316,161
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Prediction on test set

# %%
y_pred = regressor.predict(X_test) 
y_pred_original = mms.inverse_transform(y_pred.reshape(-1,1))
y_pred_original = y_pred_original.tolist()
y_pred_original = [pred for i in y_pred_original for pred in i]

# %%
test_set =pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')
submission = pd.DataFrame({'Id': test_set['Id'],'SalePrice': y_pred_original})

# %%
#submission.to_csv('submission.csv', index=False)

# %% [markdown]
# 1. **Furthur Imrovement on our submission**
#
# Training more regressors and combining it with previous one's
#
# Take more missing values into consideration

# %%
from sklearn.ensemble import RandomForestRegressor
regressor1 = RandomForestRegressor(n_estimators= 100)
regressor1.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred1 = regressor1.predict(X_test) 
y_pred_original1 = mms.inverse_transform(y_pred1.reshape(-1,1))
y_pred_original1 = y_pred_original1.tolist()
y_pred_original1 = [pred for i in y_pred_original1 for pred in i]

# %%
y_pred_final=[]
for i in range(0,1459):
    y_pred_final.append((y_pred_original[i]*0.5)+(y_pred_original1[i]*0.5))

# %%
submission = pd.DataFrame({'Id': test_set['Id'],'SalePrice': y_pred_final})

# %%
submission.to_csv('submission.csv', index=False)
